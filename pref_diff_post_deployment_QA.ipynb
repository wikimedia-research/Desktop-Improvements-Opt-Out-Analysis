# %% [markdown]
# # Pref Diff Schema Post Deployment QA
#
# [Task](https://phabricator.wikimedia.org/T261842)

# %% [markdown]
# A new schema, [mediawiki_preff_diff](https://gerrit.wikimedia.org/r/plugins/gitiles/schemas/event/secondary/+/refs/heads/master/jsonschema/analytics/pref_diff/current.yaml), was created in [T261842](https://phabricator.wikimedia.org/T261842) to track the opt-ins and opt-outs of desktop improvements and deployed on 8 April 2021. Unlike PrefUpdate, this schema logs an arbitrary `intial` and `final` state (e.g. a user switched from latest Vector to Monobook). It also allows for the use of a hashed user ID.

# %% [markdown]
# Schema  Documentation:
# * https://gerrit.wikimedia.org/r/c/mediawiki/extensions/WikimediaEvents/+/668530
# * https://gerrit.wikimedia.org/r/plugins/gitiles/schemas/event/secondary/+/refs/heads/master/jsonschema/analytics/pref_diff/current.yaml

# %% [markdown]
# **QA Checks**:
# I queried the data and looked through the following aggregations to determine if the data appears as expected based on instrumentation and time of deployment.
# * Preference changes by date [PASS]
# * Preference changes by wiki (all vs target wikis) [PASS]
# * Preference changes by initial to final state [IN PRRoGRESS - ISSUES IDENTIFIED]
#     * Updates to Vector and Modern skins vs updates to Vector 1 and 2.
# * Preference Changes by edit bucket [PASS]

# %%
shhh <- function(expr) suppressPackageStartupMessages(suppressWarnings(suppressMessages(expr)))
shhh({
    library(tidyverse); library(glue); library(lubridate); library(scales)
})

# %%
query <- 
"
SELECT
    date_format(dt, 'yyyy-MM-dd') AS `date`,
    user_hash AS `user`,
    initial_state AS initial_state,
    final_state AS final_state,
    bucketed_user_edit_count AS edit_count,
    meta.domain as wiki,
    COUNT(*) AS num_selections
FROM event.mediawiki_pref_diff
WHERE 
    year = 2021
    AND month >= 04
    AND day >= 15
GROUP BY
    date_format(dt, 'yyyy-MM-dd') ,
    user_hash,
    initial_state,
    final_state,
    bucketed_user_edit_count,
    meta.domain
"

# %%
desktop_pref_updates <-  wmfdata::query_hive(query)
# Out:
# Don't forget to authenticate with Kerberos using kinit

# %%
desktop_pref_updates$date <- as.Date(desktop_pref_updates$date, format = "%Y-%m-%d")

# %%
options(repr.plot.width = 15, repr.plot.height = 15)

# %% [markdown]
# ## Daily preference updates date across all wikis

# %%
desktop_pref_updates_events_bydate <- desktop_pref_updates %>%
    #filter(final_state %in% c('vector1', 'vector2')) %>%
    group_by(date) %>%
    summarise(total_selections = sum(num_selections),
             total_users = n_distinct(user))

desktop_pref_updates_events_bydate
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
#    date       total_selections total_users
# 1  2021-04-15  57               35
# 2  2021-04-16 297              196
# 3  2021-04-17 257              171
# 4  2021-04-18 271              174
# 5  2021-04-19 360              230
# 6  2021-04-20 300              197
# 7  2021-04-21 294              193
# 8  2021-04-22 270              177
# 9  2021-04-23 232              156
# 10 2021-04-24 254              181
# 11 2021-04-25 246              167
# 12 2021-04-26 336              216
# 13 2021-04-27 333              205
# 14 2021-04-28 361              217
# 15 2021-04-29 348              215
# 16 2021-04-30 264              178
# 17 2021-05-15 254              163
# 18 2021-05-16 300              186
# 19 2021-05-17 350              230
# 20 2021-05-18 291              201
# 21 2021-05-19 265              183
# 22 2021-05-20 329              196
# 23 2021-05-21 495              268
# 24 2021-05-22 300              201
# 25 2021-05-23 319              184
# 26 2021-05-24 356              219
# 27 2021-05-25 320              197
# 28 2021-05-26 287              190
# 29 2021-05-27 264              171
# 30 2021-05-28 267              153
# 31 2021-05-29 257              162
# 32 2021-05-30 293              181
# 33 2021-05-31 268              180

# %% [markdown]
# Events start appearing in the database on April 15th. There is an average 260 preference updates by 171 users per day. This is expected as it's possible for the same user to make more than one preference update.

# %%
p <- desktop_pref_updates %>%
    #filter(final_state %in% c('vector1', 'vector2')) %>%
    group_by(date, final_state) %>%
    summarise(total_selections = sum(num_selections),
             total_users = n_distinct(user)) %>%
    ggplot(aes(x = date, y = total_selections, color = final_state)) +
       geom_line(size = 1.5) +
        scale_x_date() +
       labs(title = "Daily number of preference update events across all wikis",
           y = "Number of selections") +
        theme_bw() +
        scale_color_brewer(name="Final State", palette="Set2")  +
        theme(
            plot.title = element_text(hjust = 0.5),
            text = element_text(size=14),
            legend.position = "bottom")

p
# Out:
# `summarise()` regrouping output by 'date' (override with `.groups` argument)
# plot without title

# %%
## Vector Events

vector_events <- desktop_pref_updates %>%
    filter(final_state == 'vector') %>%
    group_by(date, final_state) %>%
    summarise(total_selections = sum(num_selections),
             total_users = n_distinct(user)) 

vector_events
# Out:
# `summarise()` regrouping output by 'date' (override with `.groups` argument)
#    date       final_state total_selections total_users
# 1  2021-04-16 vector      13                5
# 2  2021-04-17 vector      17               12
# 3  2021-04-18 vector       7                3
# 4  2021-04-19 vector      11                6
# 5  2021-04-20 vector       1                1
# 6  2021-04-21 vector       1                1
# 7  2021-04-22 vector       3                3
# 8  2021-04-23 vector      11                7
# 9  2021-04-24 vector       4                4
# 10 2021-04-25 vector       9                6
# 11 2021-04-26 vector      37               15
# 12 2021-04-27 vector      29               15
# 13 2021-04-28 vector       6                5
# 14 2021-04-29 vector      15                8
# 15 2021-04-30 vector      10                7
# 16 2021-05-15 vector       3                2
# 17 2021-05-16 vector       4                2
# 18 2021-05-17 vector      11                6

# %% [markdown]
# Confirmed we stop recording vector events following fix: https://gerrit.wikimedia.org/r/c/mediawiki/extensions/WikimediaEvents/+/690789/ deployed on May 17th.
#
# We stop seeing flucturations from May 1st - May 15th. This was due to changes in the config due to the AB Test.

# %%
p <- desktop_pref_updates %>%
    #filter(final_state %in% c('vector1', 'vector2')) %>%
    group_by(date, final_state) %>%
    summarise(total_selections = sum(num_selections),
             total_users = n_distinct(user))  %>%
    ggplot(aes(x = date, y = total_users, color = final_state)) +
       geom_line(size = 1.5) +
       labs(title = "Daily number of preference update users by final selected state \n across all wikis",
           y = "Daily distinct users")+
        theme_bw() +
        scale_color_brewer(name="Final State", palette="Set2")  +
        theme(
            plot.title = element_text(hjust = 0.5),
            text = element_text(size=14),
            axis.title.x=element_blank(),
            axis.text.x=element_blank(),
            legend.position = "bottom")

p
# Out:
# `summarise()` regrouping output by 'date' (override with `.groups` argument)
# plot without title

# %% [markdown]
# A review of the daily number of final state preference updates by user and wiki appear as expected. The majority of preference updates each day since we began recording are for vector 1 and vector2 desktop skins. Daily trends are consistent - There are no signficant drops or spikes in the data indicating any anomalies.

# %% [markdown]
# ## Daily preference updates on target wikis by Vector Version

# %%
desktop_pref_updates_events_bydate_target <- desktop_pref_updates %>%
    filter(wiki %in% c('fr.wiktionary.org', 'he.wikipedia.org', 'pt.wikiversity.org', 'fr.wikipedia.org', 
    'eu.wikipedia.org', 'fa.wikipedia.org', 'pt.wikipedia.org', 'ko.wikipedia.org', 'tr.wikipedia.org', 
                       'sr.wikipedia.org', 'bn.wikipedia.org', 'de.wikivoyage.org', 'vec.wikipedia.org'))  %>%
    filter(final_state %in% c('vector1', 'vector2'),
          initial_state %in% c('vector1', 'vector2')) %>%
    group_by(date, wiki, final_state) %>%
    summarise(total_selections = sum(num_selections),
             total_users = n_distinct(user))
# Out:
# `summarise()` regrouping output by 'date', 'wiki' (override with `.groups` argument)

# %%
p <- desktop_pref_updates_events_bydate_target %>%
    ggplot(aes(x = date, y = total_selections, color = final_state)) +
       geom_line(size = 1.5) +
        facet_wrap (~ wiki) +
       labs(title = "Daily number of preference updates by vector version \n across all early adopter wikis",
           y = "Number of preference updates")  +
        scale_color_brewer(name="Final State", palette="Set1")  +
        theme_bw() +
        theme(
            plot.title = element_text(hjust = 0.5),
            text = element_text(size=14),
            legend.position = "bottom")

p
# Out:
# plot without title

# %%
p <- desktop_pref_updates_events_bydate_target %>%
    ggplot(aes(x = date, y = total_users, color = final_state)) +
       geom_line(size = 1.5) +
        facet_wrap (~ wiki) +
       labs(title = "Daily number of preference update users by vector version \n across all early adopter wikis",
           y = "Daily number of distinct users")  +
        scale_color_brewer(name="Final State", palette="Set1")  +
        theme_bw() +
        theme(
            plot.title = element_text(hjust = 0.5),
            text = element_text(size=14),
            legend.position = "bottom")

p
# Out:
# plot without title

# %% [markdown]
# There are more users that opt-out than opt-in as this new desktop skin (vector2) was presented as default to all logged-in users on all target wikis.
#
# There have only been 1 to 8 vector opt-in or opt-outs a day on each target wiki since April 15th

# %% [markdown]
# # Initial and Final State Selection Totals

# %% [markdown]
# # For all Wikis

# %%
desktop_pref_updates_bystate <- desktop_pref_updates %>%
    filter(date > '2021-05-17') %>% # following deployment fix
    group_by(initial_state, final_state) %>%
    summarise(total_selections = sum(num_selections),
             total_users = n_distinct(user))

desktop_pref_updates_bystate
# Out:
# `summarise()` regrouping output by 'initial_state' (override with `.groups` argument)
#    initial_state final_state        total_selections total_users
# 1  minerva       vector1            144              133
# 2  minerva       vector2            152              133
# 3  modern        vector1            102               98
# 4  modern        vector2             73               67
# 5  monobook      vector1            119              109
# 6  monobook      vector2            114              106
# 7  timeless      vector1            180              170
# 8  timeless      vector2            123              119
# 9  vector1       minerva            437              418
# 10 vector1       modern             345              338
# 11 vector1       monobook           248              235
# 12 vector1       timeless           372              364
# 13 vector1       vector2            762              649
# 14 vector1       wikimediaapiportal   1                1
# 15 vector2       minerva            168              153
# 16 vector2       modern              98               91
# 17 vector2       monobook            98               92
# 18 vector2       timeless            97               89
# 19 vector2       vector1            678              581

# %%
p <- desktop_pref_updates_bystate %>%
    ggplot(aes(x= initial_state, y = total_users, group = initial_state)) +
       geom_col(fill = "dark blue") +
        geom_text(aes(label = paste(initial_state)), color = "black", vjust=-1, size = 5) +
        facet_wrap(~ final_state) +
       labs(title = "Number of preference update users by final selected state \n across all wikis",
           y = "Number of distinct users")  +
        theme_bw() +
        theme(
            plot.title = element_text(hjust = 0.5),
            text = element_text(size=14),
            axis.title.x=element_blank(),
            axis.text.x=element_blank(),
            legend.position = "bottom")

p
# Out:
# plot without title

# %% [markdown]
# Potential Issues: We're recording a couple instances of someone going from vector 2 to vector (instead of vector 1). This was due to a bug that was fixed on 17 May.
#
# After a recheck of the data, I noticed an instance where a user switched from `initial_state = 'vector1'` to `final_state = 'wikimediaapiportal'`

# %%
head(desktop_pref_updates)
# Out:
#   date
# 1 2021-04-15
# 2 2021-04-15
# 3 2021-04-15
# 4 2021-04-15
# 5 2021-04-15
# 6 2021-04-15
#   user
# 1 00cfaafe818b6da3e5487a7f6326afd8f69e952c5227cfc8d3aee50368917d1b21b9fc073965a077c727bcfeede77d12965012dad42f5db50723194432d13271
# 2 23801399a076d16cc990b560e8a036800b99c014028390294b7a1d1ab7564f1e69ca1b081e2b5b880c034afe4946a6951ec9a5e1a38104e498dc031bc2decce3
# 3 23801399a076d16cc990b560e8a036800b99c014028390294b7a1d1ab7564f1e69ca1b081e2b5b880c034afe4946a6951ec9a5e1a38104e498dc031bc2decce3
# 4 23801399a076d16cc990b560e8a036800b99c014028390294b7a1d1ab7564f1e69ca1b081e2b5b880c034afe4946a6951ec9a5e1a38104e498dc031bc2decce3
# 5 23801399a076d16cc990b560e8a036800b99c014028390294b7a1d1ab7564f1e69ca1b081e2b5b880c034afe4946a6951ec9a5e1a38104e498dc031bc2decce3
# 6 257dfc3b24425759a3f9a32592dcdd559d9a4587bd3018b05f9214896d14aed37c6524fcdac17ff3d2e18bdd83f38aaa126e9363941f22bbb79e4568c4d84980
#   initial_state final_state edit_count  wiki             num_selections
# 1 vector1       modern      0 edits     de.wikipedia.org 1
# 2 timeless      vector1     1000+ edits fr.wikipedia.org 1
# 3 vector1       vector2     1000+ edits fr.wikipedia.org 2
# 4 vector2       timeless    1000+ edits fr.wikipedia.org 1
# 5 vector2       vector1     1000+ edits fr.wikipedia.org 1
# 6 vector2       timeless    0 edits     tr.wikipedia.org 1

# %%
## Look into wikimediapiportal switch

wikimediapiportal_events <- desktop_pref_updates %>%
    filter(final_state== 'wikimediaapiportal')

wikimediapiportal_events
# Out:
#   date
# 1 2021-05-19
#   user
# 1 44184be8b844f70ae57a7c7b7e8440d3dda86d9772842fc71d09acac1d545a60f3c3cc89bea6547a2cb3e81a1f8a152011633db36a723d6e6b213e224dd6e2cf
#   initial_state final_state        edit_count wiki              num_selections
# 1 vector1       wikimediaapiportal 0 edits    api.wikimedia.org 1

# %% [markdown]
# ## For Target Wikis

# %%
desktop_pref_updates_bystate_target <- desktop_pref_updates %>%
    filter(wiki %in% c('fr.wiktionary.org', 'he.wikipedia.org', 'pt.wikiversity.org', 'fr.wikipedia.org', 
    'eu.wikipedia.org', 'fa.wikipedia.org', 'pt.wikipedia.org', 'ko.wikipedia.org', 'tr.wikipedia.org', 
                       'sr.wikipedia.org', 'bn.wikipedia.org', 'de.wikivoyage.org', 'vec.wikipedia.org'),
             date > '2021-05-17' )  %>%
    group_by(initial_state, final_state) %>%
    summarise(total_selections = sum(num_selections),
             total_users = n_distinct(user))

desktop_pref_updates_bystate_target
# Out:
# `summarise()` regrouping output by 'initial_state' (override with `.groups` argument)
#    initial_state final_state total_selections total_users
# 1  minerva       vector1       8                8
# 2  minerva       vector2      43               41
# 3  modern        vector1       6                6
# 4  modern        vector2      22               22
# 5  monobook      vector1       9                9
# 6  monobook      vector2      29               28
# 7  timeless      vector1      12               12
# 8  timeless      vector2      30               30
# 9  vector1       minerva      10               10
# 10 vector1       modern        9                9
# 11 vector1       monobook     10               10
# 12 vector1       timeless     14               13
# 13 vector1       vector2      83               75
# 14 vector2       minerva      80               77
# 15 vector2       modern       58               57
# 16 vector2       monobook     42               42
# 17 vector2       timeless     49               46
# 18 vector2       vector1     190              177

# %%
p <- desktop_pref_updates_bystate_target %>%
    ggplot(aes(x= initial_state, y = total_users, group = initial_state)) +
     geom_col(fill = "dark blue") +
        geom_text(aes(label = paste(initial_state)), color = "black", vjust=-1, size = 5) +
        facet_wrap(~ final_state) +
       labs(title = "Number of preference update users by final selected state \n across all target wikis",
           y = "Number of distinct users",
           subtitle = "Each bar represents the initial state and each chart the final state") + 
        theme_bw() +
        theme(
            plot.title = element_text(hjust = 0.5),
            text = element_text(size=14),
            axis.title.x=element_blank(),
            axis.text.x=element_blank(),
            legend.position = "bottom")


p
# Out:
# plot without title

# %% [markdown]
# The number of updates to each available desktop skin appears to fit with current config states. For the target wikis, the majority of users updated their preferences from vector2 to vector1, which is expected since vector 2 was deployed as opt-out to all of the pilot wikis. Users would only need to explicility update their preference to Vector1 from Vector2 if they opt-out and then decided to opt back in again.
#
# We see more users update from vector 1 to vector 2 when looking across all wikis since it is available as an opt-in preference across all wikis.

# %% [markdown]
# ## Vector 2 to Vector Switches

# %%
vec2_to_vector <- desktop_pref_updates %>%
    filter(initial_state == 'vector2',
          final_state == 'vector') %>%
    group_by( wiki) %>%
    summarise(total_selections = sum(num_selections),
             total_users = n_distinct(user)) 


vec2_to_vector
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
#    wiki                  total_selections total_users
# 1  bn.wikipedia.org       1                1
# 2  bn.wikisource.org      1                1
# 3  bn.wikivoyage.org      1                1
# 4  bs.wikipedia.org       4                2
# 5  commons.wikimedia.org  4                3
# 6  de.wikipedia.org       3                1
# 7  en.wikinews.org        2                1
# 8  en.wikipedia.org      35               14
# 9  en.wikisource.org      4                1
# 10 en.wikivoyage.org      2                1
# 11 en.wiktionary.org      4                2
# 12 fr.wikipedia.org       9                2
# 13 it.wikipedia.org       5                2
# 14 ja.wikinews.org        1                1
# 15 ja.wikipedia.org       9                1
# 16 meta.wikimedia.org     3                3
# 17 pt.wikipedia.org       6                2
# 18 ru.wikipedia.org       3                1
# 19 simple.wikipedia.org   6                2
# 20 species.wikimedia.org  1                1
# 21 test.wikipedia.org     3                3
# 22 www.wikidata.org       4                2
# 23 zh.wikipedia.org       5                4
# 24 zh.wiktionary.org      1                1

# %% [markdown]
# The vector2 to vector switch across a number of different wiki projects including test and non-test wikis so there doesn't seem to be a correlation there.

# %%
vec2_to_vector_daily <- desktop_pref_updates %>%
    filter(initial_state == 'vector2',
          final_state == 'vector') %>%
    group_by(date, wiki) %>%
    summarise(total_selections = sum(num_selections),
             total_users = n_distinct(user)) 
vec2_to_vector_daily
# Out:
# `summarise()` regrouping output by 'date' (override with `.groups` argument)
#    date       wiki                  total_selections total_users
# 1  2021-04-16 commons.wikimedia.org  1               1
# 2  2021-04-16 en.wikipedia.org       3               1
# 3  2021-04-16 en.wiktionary.org      1               1
# 4  2021-04-16 fr.wikipedia.org       7               1
# 5  2021-04-16 zh.wikipedia.org       1               1
# 6  2021-04-17 commons.wikimedia.org  1               1
# 7  2021-04-17 en.wikinews.org        2               1
# 8  2021-04-17 en.wikipedia.org       8               4
# 9  2021-04-17 en.wikisource.org      1               1
# 10 2021-04-17 ja.wikinews.org        1               1
# 11 2021-04-17 meta.wikimedia.org     1               1
# 12 2021-04-17 ru.wikipedia.org       1               1
# 13 2021-04-17 simple.wikipedia.org   1               1
# 14 2021-04-17 www.wikidata.org       1               1
# 15 2021-04-18 en.wikipedia.org       2               1
# 16 2021-04-18 it.wikipedia.org       4               1
# 17 2021-04-18 pt.wikipedia.org       1               1
# 18 2021-04-19 de.wikipedia.org       3               1
# 19 2021-04-19 en.wikipedia.org       1               1
# 20 2021-04-19 en.wikisource.org      3               1
# 21 2021-04-19 www.wikidata.org       3               2
# 22 2021-04-19 zh.wikipedia.org       1               1
# 23 2021-04-20 ru.wikipedia.org       1               1
# 24 2021-04-21 zh.wikipedia.org       1               1
# 25 2021-04-22 en.wikipedia.org       1               1
# 26 2021-04-22 pt.wikipedia.org       1               1
# 27 2021-04-22 zh.wikipedia.org       1               1
# 28 2021-04-23 en.wikipedia.org       8               4
# 29 2021-04-23 meta.wikimedia.org     1               1
# 30 2021-04-23 ru.wikipedia.org       1               1
# 31 2021-04-23 species.wikimedia.org  1               1
# 32 2021-04-24 en.wikipedia.org       1               1
# 33 2021-04-24 en.wiktionary.org      1               1
# 34 2021-04-24 test.wikipedia.org     1               1
# 35 2021-04-24 zh.wiktionary.org      1               1
# 36 2021-04-25 bn.wikipedia.org       1               1
# 37 2021-04-25 bn.wikisource.org      1               1
# 38 2021-04-25 commons.wikimedia.org  1               1
# 39 2021-04-25 it.wikipedia.org       1               1
# 40 2021-04-25 pt.wikipedia.org       4               1
# 41 2021-04-25 zh.wikipedia.org       1               1
# 42 2021-04-26 bn.wikivoyage.org      1               1
# 43 2021-04-26 bs.wikipedia.org       4               2
# 44 2021-04-26 commons.wikimedia.org  1               1
# 45 2021-04-26 en.wikipedia.org      10               5
# 46 2021-04-26 en.wikivoyage.org      2               1
# 47 2021-04-26 en.wiktionary.org      2               1
# 48 2021-04-26 fr.wikipedia.org       2               1
# 49 2021-04-26 ja.wikipedia.org       9               1
# 50 2021-04-26 simple.wikipedia.org   5               1
# 51 2021-04-26 test.wikipedia.org     1               1
# 52 2021-04-27 en.wikipedia.org       1               1
# 53 2021-04-27 meta.wikimedia.org     1               1
# 54 2021-04-27 test.wikipedia.org     1               1

# %% [markdown]
# No sharp increases or declines by date or wiki. Most of these switches from 'vector2' to 'vector' occur on en.wikpedia or zh.wikipedia.

# %% [markdown]
# # By User Edit Bucket

# %%
# set factor levels
desktop_pref_updates$edit_count <- factor(desktop_pref_updates$edit_count, levels = c("0 edits", "1-4 edits",
                                                                                     "5-99 edits", "100-999 edits",
                                                                                     "1000+ edits"))

# %% [markdown]
# ## Across all wikis

# %%
desktop_pref_updates_usercount <- desktop_pref_updates %>%
    group_by(edit_count) %>%
    summarise(total_selections = sum(num_selections),
             total_users = n_distinct(user))

desktop_pref_updates_usercount
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
#   edit_count    total_selections total_users
# 1 0 edits       1425             1012
# 2 1-4 edits      488              324
# 3 5-99 edits     715              421
# 4 100-999 edits  318              158
# 5 1000+ edits    437              192

# %% [markdown]
# The data by edit count appears as expected. We see the most preference switches by users with 0 edits. Almost half of all the preference updates come from users with 0 edits (48.03%). For editors (those that have made at least 1 edit), the majority of desktop preference updates (68%) are by users with under 99 edits.

# %% [markdown]
# ## Target Wikis Only (Isolated to Only Vector Version Switches)

# %%
desktop_pref_updates_usercount_target <- desktop_pref_updates %>%
    filter(wiki %in% c('fr.wiktionary.org', 'he.wikipedia.org', 'pt.wikiversity.org', 'fr.wikipedia.org', 
    'eu.wikipedia.org', 'fa.wikipedia.org', 'pt.wikipedia.org', 'ko.wikipedia.org', 'tr.wikipedia.org', 
                       'sr.wikipedia.org', 'bn.wikipedia.org', 'de.wikivoyage.org', 'vec.wikipedia.org')) %>%
    filter(final_state %in% c('vector1', 'vector2'),
          initial_state %in% c('vector1', 'vector2')) %>%
    group_by(edit_count, final_state) %>%
    summarise(total_selections = sum(num_selections),
             total_users = n_distinct(user))

desktop_pref_updates_usercount_target
# Out:
# `summarise()` regrouping output by 'edit_count' (override with `.groups` argument)
#    edit_count    final_state total_selections total_users
# 1  0 edits       vector1     71               68
# 2  0 edits       vector2      9                8
# 3  1-4 edits     vector1     29               29
# 4  1-4 edits     vector2      2                2
# 5  5-99 edits    vector1     46               42
# 6  5-99 edits    vector2     13               11
# 7  100-999 edits vector1     25               23
# 8  100-999 edits vector2     10               10
# 9  1000+ edits   vector1     34               30
# 10 1000+ edits   vector2     23               18
